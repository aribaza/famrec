# %%
import numpy as np
import draw_eight

# %% [markdown]
# hello ! this is a markdown cell

# %%
print ("Hello!")

my_array = np.array([1, 2, 3, 4, 5])
print(my_array)

draw_eight.make_figure()
# Out:
# Hello!
# [1 2 3 4 5]

# %%
for item in ['banana', "", 37, 0, 0.5, None, False]:
    if item:
        print("item:", item)
# Out:
# item: banana
# item: 37
# item: 0.5
